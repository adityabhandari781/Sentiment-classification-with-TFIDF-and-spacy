# %%
import pandas as pd

# %%
df = pd.read_csv('data/train.txt', delimiter=';', names=['comment', 'emotion'])

# %%
df.shape
# Out:
# (16001, 2)

# %%
df.head()
# Out:
#                                              comment  emotion
# 0                                               Text  Emotion
# 1                            i didnt feel humiliated  sadness
# 2  i can go from feeling so hopeless to so damned...  sadness
# 3   im grabbing a minute to post i feel greedy wrong    anger
# 4  i am ever feeling nostalgic about the fireplac...     love

# %%
hash = {s:i for i,s in enumerate(df['emotion'].unique())}
hash
# Out:
# {'Emotion': 0,
#  'sadness': 1,
#  'anger': 2,
#  'love': 3,
#  'surprise': 4,
#  'fear': 5,
#  'joy': 6}

# %%
df['emotion_num'] = df['emotion'].map(hash)
df.head()
# Out:
#                                              comment  emotion  emotion_num
# 0                                               Text  Emotion            0
# 1                            i didnt feel humiliated  sadness            1
# 2  i can go from feeling so hopeless to so damned...  sadness            1
# 3   im grabbing a minute to post i feel greedy wrong    anger            2
# 4  i am ever feeling nostalgic about the fireplac...     love            3

# %%
test_df = pd.read_csv('data/test.txt', delimiter=';', names=['comment', 'emotion'])
test_df = pd.read_csv('data/test.txt', delimiter=';', names=['comment', 'emotion'])

# %%
X_train = df['comment']
X_test = test_df['comment']
X_train.shape, X_test.shape
# Out:
# ((16001,), (2001,))

# %%
test_df['emotion_num'] = test_df['emotion'].map(hash)
y_train = df['emotion_num']
y_test = test_df['emotion_num']
y_train.shape, y_test.shape
# Out:
# ((16001,), (2001,))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
clf = Pipeline([
    ('cv', CountVectorizer(ngram_range=(3, 3))),
    ('forest', RandomForestClassifier())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('cv', CountVectorizer(ngram_range=(3, 3))),
#                 ('forest', RandomForestClassifier())])

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.61      0.36      0.45       581
#            2       0.44      0.20      0.28       275
#            3       0.43      0.12      0.19       159
#            4       0.50      0.14      0.21        66
#            5       0.47      0.21      0.29       224
#            6       0.44      0.86      0.58       695
#
#     accuracy                           0.47      2001
#    macro avg       0.41      0.27      0.29      2001
# weighted avg       0.49      0.47      0.43      2001
# c:\Users\adity\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\adity\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\adity\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pandas as pd

# %%
from sklearn.naive_bayes import MultinomialNB
clf = Pipeline([
    ('cv', CountVectorizer(ngram_range=(1, 2))),
    ('nb', MultinomialNB())
])
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      0.89      0.76       581
#            2       0.95      0.28      0.44       275
#            3       0.80      0.05      0.09       159
#            4       0.00      0.00      0.00        66
#            5       0.90      0.35      0.50       224
#            6       0.64      0.96      0.77       695
#
#     accuracy                           0.68      2001
#    macro avg       0.56      0.36      0.37      2001
# weighted avg       0.71      0.68      0.61      2001
# c:\Users\adity\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\adity\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\adity\anaconda3\envs\myenv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#1. create a pipeline object

clf = Pipeline([
    ('cv', CountVectorizer(ngram_range = (1, 2))),
    ('rf', RandomForestClassifier())
])


#2. fit with X_train and y_train

clf.fit(X_train, y_train)

#3. get the predictions for X_test and store it in y_pred

y_pred = clf.predict(X_test)

#4. print the classfication report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       0.93      0.91      0.92       581
#            2       0.91      0.80      0.85       275
#            3       0.88      0.57      0.69       159
#            4       0.76      0.53      0.62        66
#            5       0.92      0.77      0.84       224
#            6       0.79      0.97      0.87       695
#
#     accuracy                           0.86      2001
#    macro avg       0.88      0.79      0.83      2001
# weighted avg       0.87      0.86      0.86      2001

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


clf = Pipeline([
     ('tfidf',TfidfVectorizer()),        
     ('rf', RandomForestClassifier())         
])

clf.fit(X_train, y_train)


y_pred = clf.predict(X_test)


#4. print the classfication report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       0.92      0.90      0.91       581
#            2       0.89      0.84      0.86       275
#            3       0.81      0.62      0.70       159
#            4       0.66      0.58      0.61        66
#            5       0.87      0.82      0.85       224
#            6       0.83      0.94      0.88       695
#
#     accuracy                           0.86      2001
#    macro avg       0.85      0.81      0.83      2001
# weighted avg       0.86      0.86      0.86      2001

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
def preprocess(text):
    doc = nlp(text)
    filtered_tokens = []
    for token in doc:
        if not token.is_stop and not token.is_punct:
            filtered_tokens.append(token.lemma_)
    return ' '.join(filtered_tokens)

# %%
df['preprocessed'] = df['comment'].apply(preprocess)

# %%
test_df['preprocessed'] = test_df['comment'].apply(preprocess)

# %%
clf = Pipeline([
    ('cv', CountVectorizer(ngram_range = (1, 2))),
    ('rf', (RandomForestClassifier()))         
])
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       0.92      0.90      0.91       581
#            2       0.92      0.79      0.85       275
#            3       0.84      0.61      0.71       159
#            4       0.76      0.53      0.62        66
#            5       0.90      0.78      0.84       224
#            6       0.79      0.96      0.87       695
#
#     accuracy                           0.86      2001
#    macro avg       0.88      0.79      0.83      2001
# weighted avg       0.86      0.86      0.85      2001

# %%
clf = Pipeline([
     ('tfidf',TfidfVectorizer()),
     ('rf', RandomForestClassifier())         
])
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       0.93      0.90      0.91       581
#            2       0.89      0.82      0.86       275
#            3       0.83      0.64      0.72       159
#            4       0.68      0.58      0.62        66
#            5       0.87      0.86      0.87       224
#            6       0.83      0.94      0.88       695
#
#     accuracy                           0.87      2001
#    macro avg       0.86      0.82      0.84      2001
# weighted avg       0.87      0.87      0.86      2001
